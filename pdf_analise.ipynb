# %% [markdown]
# Criando pdf da análise

# %%
from fpdf import FPDF

class PDF(FPDF):
    def doc_title(self, label):
        self.set_font("helvetica", "B",16)
        self.cell(0, 10, label, 0, 1, "C")
        self.ln()
    
    def doc_text(self, text):
        self.set_font("helvetica", "",12)
        self.multi_cell(0, 7, text)
        self.ln()
    
    def doc_image(self, img, x, y, w, h):
        self.image(img, x, y, w, h)

pdf = PDF()
pdf.add_page()

pdf.doc_title("Análise do ensino superior brasileiro na Região Sudeste")

pdf.doc_text("O ensino superior no Brasil desempenha um papel vital no desenvolvimento socioeconômico do país. Nas últimas décadas, tem sido marcado por mudanças, desafios e oportunidades, especialmente na região Sudeste, que abriga muitas instituições de ensino superior e uma ampla variedade de cursos acadêmicos.")

pdf.doc_text("Este trabalho se concentra na análise do ensino superior no Brasil, com destaque para a região Sudeste. E examina fatores como a concentração da oferta de cursos, suas modalidades e grau de especialização. Explora a importância da região Sudeste como a região onde existe a maior oferta de cursos.")

pdf.doc_image("img/mapa-sudeste.jpg", 40, 120, 150, 100)

pdf.ln(130)
pdf.doc_text("O estudo visa proporcionar uma compreensão do estado atual do ensino superior na região, identificando áreas de melhoria e oportunidades para combater a desigualdade e promover uma educação de qualidade.")

pdf.ln(70)
pdf.doc_title("Distribuição dos cursos na região sudeste")

pdf.doc_text("A análise da região Sudeste do Brasil revela uma distribuição desigual da participação no ensino superior entre seus estados.")

pdf.doc_text("Começamos com São Paulo que se destaca como o líder, com uma significativa parcela de 48,56% das instituições e estudantes universitários da região, indicando sua posição de destaque no cenário educacional. Minas Gerais, com 31,22%, também possui uma presença substancial no ensino superior, embora em menor medida do que São Paulo. O Rio de Janeiro contribui com 13,81%, enquanto o Espírito Santo, com 6,42%, representa uma porção mais modesta, mas ainda relevante, do sistema educacional da região Sudeste.")

pdf.doc_text("Essa distribuição desigual pode ter implicações significativas no acesso à educação superior e no desenvolvimento educacional de cada estado, destacando a importância de políticas que busquem promover a equidade e a qualidade educacional em toda a região.")

pdf.doc_image("grafico_regiao.png", 20, 130, 170, 130)

pdf.ln(140)
pdf.doc_title("Análise individual de cada estado")

pdf.doc_text("Nesta análise do ensino superior na região Sudeste do Brasil, adentraremos nas particularidades de cada estado que compõe essa região diversificada e influente. Embora a região como um todo desempenhe um papel vital no contexto educacional do país, é essencial compreender que São Paulo, Minas Gerais, Rio de Janeiro e Espírito Santo possuem características únicas e desafios específicos em relação ao ensino superior. Portanto, este estudo se propõe a realizar uma análise individual de cada estado, examinando seus sistemas de ensino superior, destacando a oferta de cursos, a variedade de modalidades educacionais disponíveis e a predominância do grau da especialização oferecida em cada região.")

pdf.doc_title("Análise do estado de São Paulo")

pdf.doc_text("O estado de São Paulo, o mais populoso e economicamente desenvolvido da região Sudeste, desempenha um papel preponderante no cenário do ensino superior, contribuindo com uma impressionante parcela de 48,56% dos cursos ofertados na região. Com uma vasta gama de instituições de ensino superior, São Paulo é um polo educacional vibrante e diversificado, abrigando cursos que englobam desde ciências exatas e humanas até tecnologia e saúde. Além disso, o estado oferece uma ampla variedade de modalidades educacionais, desde cursos presenciais de alta qualidade até opções de ensino a distância, atendendo a uma demanda diversificada de estudantes.")

pdf.doc_text("A presença de São Paulo no panorama educacional do Sudeste não apenas reflete sua influência socioeconômica, mas também destaca a importância do estado como um centro de excelência acadêmica e oportunidades educacionais para toda a região.")

pdf.doc_text("No grafico da análise do grau de especialização dos cursos oferecidos na região Sudeste, destacam-se algumas tendências notáveis.Ocupando o primeiro lugar, observamos uma significativa preferência por cursos de tecnólogo, refletindo a crescente demanda por capacitação rápida e específica para o mercado de trabalho. Em segundo lugar, os cursos de bacharelado continuam a ser uma escolha popular entre os estudantes, proporcionando uma formação mais abrangente em diversas áreas. A licenciatura ocupa a terceira posição, evidenciando o interesse em formação para atuação na educação básica. Os cursos sequenciais, ocupando o quarto lugar, oferecem uma alternativa valiosa para aquisição de conhecimentos especializados. Por fim, a Área Básica de Ingresso (ABI) representa a quinta opção, indicando uma busca pela consolidação de conhecimentos fundamentais antes de ingressar em cursos mais específicos. ")

pdf.doc_text("Essa análise ressalta a diversidade e a adaptação do ensino superior na região Sudeste às necessidades variadas dos estudantes e do mercado.")

pdf.doc_image("grafico_grau_sp.png", 10, 25, 190, 100)

pdf.ln(100)
pdf.doc_text("Analisando as modalidades de cursos na região Sudeste vemos uma predominância significativa do ensino a distância (EaD), representando 89,34% das opções educacionais. Isso reflete a crescente demanda por flexibilidade e acessibilidade por parte dos estudantes em uma região geograficamente vasta. Embora em menor proporção, o ensino presencial ainda é relevante, com 10,76% das modalidades de cursos disponíveis. Essa variedade de modalidades destaca a capacidade de adaptação do sistema educacional às diversas necessidades dos estudantes.")

pdf.doc_image("grafico_modalidade_sp.png", 20, 180, 170, 130)

pdf.ln(100)
pdf.doc_title("Análise do estado de Minas Gerais")

pdf.doc_text("O estado de Minas Gerais, ocupando o segundo lugar na oferta de cursos na região Sudeste com uma parcela significativa de 31,22%, destaca-se como um polo educacional influente. Além da quantidade, Minas Gerais também se distingue pela qualidade de suas instituições de ensino superior. Cidades como Belo Horizonte, Juiz de Fora, e Uberlândia abrigam diversos polos educacionais que atraem estudantes de todo o país.")

pdf.doc_text("Minas Gerais oferece uma ampla gama de cursos, desde tecnólogos focados no mercado de trabalho até bacharelados e licenciaturas que promovem uma educação mais abrangente. Essa diversidade de opções, aliada à presença de polos educacionais estrategicamente distribuídos, torna Minas Gerais um importante centro de excelência acadêmica na região Sudeste, contribuindo para o desenvolvimento educacional e socioeconômico do estado e do Brasil como um todo.")

pdf.doc_text("Na análise do grau de especialização dos cursos disponíveis em Minas Gerais, observa-se uma preferência marcante pelo tecnólogo, ocupando o primeiro lugar na escolha dos estudantes. Em segundo lugar, os cursos de bacharelado mantêm sua relevância, proporcionando uma formação mais abrangente. A licenciatura ocupa o terceiro lugar, evidenciando o interesse em formação para atuação na educação básica. A Área Básica de Ingresso (ABI) surge como a quarta opção, indicando a busca pela consolidação de conhecimentos fundamentais. E o ensino sequencial não está entre as ofertas.")

pdf.doc_image("grafico_grau_mg.png", 10, 165, 190, 100)

pdf.ln(110)
pdf.doc_text("Na análise das modalidades de cursos disponíveis em Minas Gerais revela uma clara tendência em direção ao ensino a distância (EaD), representando expressivos 93,22% das opções educacionais. Esse predomínio do EaD pode ser justificado por diversos fatores, como a busca por flexibilidade de horários, a acessibilidade a cursos de instituições renomadas que estão fora do alcance geográfico dos estudantes e a adaptação às demandas impostas pela pandemia de COVID-19.")

pdf.doc_text("Por outro lado, embora em uma proporção menor, o ensino presencial ainda mantém sua relevância, respondendo por 6,78% das modalidades de cursos disponíveis. Essa modalidade presencial continua a ser valorizada em áreas que exigem laboratórios práticos, interações pessoais intensivas ou formações específicas que demandam a presença física em sala de aula. Portanto, essa diversificação de modalidades busca equilibrar a conveniência e a qualidade da educação oferecida em Minas Gerais.")

pdf.doc_image("grafico_modalidade_mg.png", 20, 100, 170, 130)

pdf.ln(170)
pdf.doc_title("Análise do estado do Rio de Janeiro")

pdf.doc_text("O estado do Rio de Janeiro, ocupa a terceira posição na oferta de cursos na região Sudeste, com uma parcela de 13,81%, evidencia sua relevância no cenário educacional por meio de exemplos concretos. Isso inclui a presença de renomadas instituições de ensino superior, como a Universidade Federal do Rio de Janeiro (UFRJ) e a Universidade Estadual do Rio de Janeiro (UERJ), ambas conhecidas por sua excelência acadêmica e contribuições significativas para diversas áreas do conhecimento.")

pdf.doc_text("Além disso, a cidade do Rio de Janeiro também é palco de importantes centros de pesquisa, museus e eventos acadêmicos de âmbito internacional, que atraem estudantes, pesquisadores e professores de todo o Brasil e do mundo. A diversidade cultural e econômica da região carioca amplia ainda mais as opções de cursos, com destaque para áreas como turismo, hotelaria, entretenimento e tecnologia, que se beneficiam do ambiente único da cidade.")

pdf.doc_text("No contexto da análise dos cursos disponíveis no Rio de Janeiro, observamos uma preferência expressiva pelo tecnólogo, que ocupa o primeiro lugar entre as escolhas dos estudantes. Essa preferência reflete a demanda por uma formação mais direcionada ao mercado de trabalho e às necessidades específicas da indústria, que é uma característica marcante do estado, com sua economia diversificada e complexa. Em segundo lugar, os cursos de bacharelado mantêm sua relevância, proporcionando uma formação mais abrangente em diversas áreas do conhecimento, em consonância com a oferta variada de empregos e carreiras disponíveis no estado. A licenciatura surge em terceiro lugar, indicando o interesse em formação para atuação no setor educacional, uma vez que o Rio de Janeiro abriga um grande número de escolas e instituições de ensino. A Área Básica de Ingresso (ABI) já não apresenta uma posição válida e significativa nesta análise.")

pdf.doc_image("grafico_grau_rj.png", 10, 190, 190, 100)
             
pdf.ln(80)
pdf.doc_text("Vale ressaltar que a ausência de cursos sequenciais no gráfico pode ser devido à sua menor oferta no estado, o que reflete as preferências e demandas dos estudantes do Rio de Janeiro em relação à formação superior.")

pdf.doc_text("E na análise das modalidades de cursos disponíveis no estado do Rio de Janeiro revela uma clara preferência pelo ensino a distância (EaD), que representa a expressiva parcela de 88,51% das opções educacionais.")

pdf.doc_text("Essa predominância do EaD pode ser justificada por diversos fatores, incluindo a necessidade de flexibilidade de horários para acomodar a vida agitada da população carioca, a busca por uma formação de qualidade em instituições de ensino de renome que oferecem cursos a distância e a adaptação às circunstâncias impostas pela pandemia de COVID-19. Além disso, o Rio de Janeiro é um estado com desafios de mobilidade urbana, e o EaD oferece uma solução conveniente para estudantes que preferem evitar longos deslocamentos. A modalidade presencial, embora em menor proporção, ainda é relevante, especialmente em áreas que exigem laboratórios práticos e interações presenciais, como cursos da área de saúde e artes cênicas, demonstrando a busca pelo equilíbrio entre conveniência e qualidade da educação oferecida no estado.")

pdf.doc_image("grafico_modalidade_rj.png", 20, 140, 170, 130)

pdf.ln(170)
pdf.doc_title("Análise do estado do Espirito Santo")

pdf.doc_text("O estado do Espírito Santo, que ocupa a última posição na oferta de cursos na região Sudeste, com uma participação de apenas 6,42%, destaca-se por características peculiares que contribuem para essa posição.")

pdf.doc_text("O Espírito Santo é geograficamente menor em comparação com outros estados da região e possui uma população relativamente menor, o que naturalmente resulta em uma oferta mais limitada de cursos e instituições de ensino superior. Além disso, sua economia está predominantemente voltada para setores como a indústria e a agricultura, o que pode influenciar a demanda por cursos acadêmicos. No entanto, vale ressaltar que o estado tem investido em sua infraestrutura educacional e busca expandir a oferta de cursos para atender às necessidades crescentes de qualificação da população e promover o desenvolvimento econômico.")

pdf.doc_text("Assim, embora ocupe a última posição em termos de oferta de cursos, o Espírito Santo demonstra um potencial de crescimento e desenvolvimento educacional que pode contribuir para sua ascensão no cenário educacional da região Sudeste.")

pdf.doc_text("Na análise do grau de especialização dos cursos disponíveis no estado do Espírito Santo, destaca-se a preferência pelo tecnólogo, ocupando o primeiro lugar entre as escolhas dos estudantes. Essa tendência pode ser atribuída ao perfil econômico do estado, que valoriza profissionais com habilidades técnicas específicas para atender às demandas de setores como o petróleo e a indústria portuária.")

pdf.doc_image("grafico_grau_es.png", 10, 180, 190, 100)

pdf.ln(130)
pdf.doc_text("Em segundo lugar, os cursos de bacharelado mantêm sua relevância, proporcionando uma formação mais abrangente, principalmente para áreas como administração e engenharias. A licenciatura surge em terceiro lugar, indicando o interesse em formação para atuação no setor educacional, que é fundamental para o desenvolvimento da educação básica na região. A opção pela Área Básica de Ingresso (ABI) como a quarta escolha sugere uma busca por uma formação mais sólida em conhecimentos fundamentais antes de ingressar em cursos mais específicos.")

pdf.doc_text("A presença de cursos sequenciais em quinto lugar, embora menos comum, pode estar relacionada à oferta limitada de cursos nessa modalidade ou à preferência dos estudantes por cursos de maior duração e abrangência. Esses dados refletem a interação complexa entre a economia e as demandas educacionais do estado, que moldam as preferências dos estudantes por diferentes tipos de cursos")

pdf.doc_text("E na análise das modalidades de cursos disponíveis no estado do Espírito Santo revela uma clara preferência pelo ensino a distância (EaD), representando uma expressiva parcela de 93,58% das opções educacionais. Essa predominância do EaD pode ser justificada por diversas razões. Primeiramente, o Espírito Santo é um estado que apresenta uma geografia desafiadora, com distâncias significativas entre cidades e regiões, o que torna o ensino a distância uma opção conveniente para estudantes que desejam evitar longos deslocamentos.")

pdf.doc_image("grafico_modalidade_es.png", 20, 150, 170, 130)

pdf.ln(130)
pdf.doc_text(" Além disso, o EaD permite maior flexibilidade de horários, o que se adequa às agendas ocupadas da população, muitas vezes envolvida em setores como o agronegócio e a indústria. A modalidade presencial, embora menos prevalente, ainda é relevante, especialmente em cursos que demandam laboratórios práticos e interações pessoais, como ciências da saúde e engenharia.")

pdf.doc_text("Portanto, essa distribuição reflete a busca por uma educação acessível e flexível no Espírito Santo, que atenda às demandas variadas dos estudantes e às condições geográficas específicas do estado.")

pdf.doc_title("Conclusão")

pdf.doc_text("Após analisarmos o panorama do ensino superior na região Sudeste do Brasil, é evidente que cada estado apresenta características distintas, refletindo suas particularidades socioeconômicas, demográficas e estruturais. No entanto, algumas semelhanças significativas emergem nos quesitos de grau e modalidade dos cursos oferecidos.")

pdf.doc_text("A predominância do ensino a distância (EaD) em todos os estados da região Sudeste destaca-se como uma característica marcante. Essa preferência pode ser relacionada à flexibilidade de horários, às vantagens em termos de acesso a cursos oferecidos por instituições renomadas e à adaptação às novas necessidades, como as impostas pela pandemia. A modalidade presencial, embora menos predominante, ainda é valorizada, especialmente em áreas que demandam experiências práticas e interações presenciais.")

pdf.doc_text("Essas semelhanças nos padrões de grau e modalidade de cursos na região Sudeste podem ser reflexo do cenário de desigualdade educacional no país. A preferência por cursos mais técnicos, como os tecnólogos, pode estar ligada à busca por inserção rápida no mercado de trabalho, evidenciando a influência das desigualdades sociais e a necessidade de ascensão econômica em um país com marcadas disparidades. Além disso, a predominância do EaD pode refletir a necessidade de ampliar o acesso à educação superior em regiões com características geográficas desafiadoras e desigualdades de infraestrutura.")

pdf.doc_text("Em conclusão, compreender as semelhanças e nuances nos padrões educacionais da região Sudeste é fundamental para desenvolver políticas educacionais mais inclusivas e eficazes. Ao direcionar esforços para garantir a qualidade e acessibilidade do ensino, especialmente no contexto do ensino a distância, é possível contribuir para a redução das desigualdades educacionais e promover uma educação superior equitativa e enriquecedora para todos os brasileiros.")

pdf.output("analise.pdf")
# Out:
# C:\Users\ALEX\AppData\Local\Temp\ipykernel_9820\252878111.py:6: DeprecationWarning: The parameter "ln" is deprecated. Instead of ln=1 use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   self.cell(0, 10, label, 0, 1, "C")
